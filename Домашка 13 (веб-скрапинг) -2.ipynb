# %% [markdown]
# - Обязательная часть
#
# Вам необходимо написать функцию, которая будет основана на поиске по сайту habr.com. Функция в качестве параметра должна принимать список запросов для поиска (например, ['python', 'анализ данных']) и на основе материалов, попавших в результаты поиска по каждому запросу, возвращать датафрейм вида:
#
#
# <дата> - <заголовок> - <ссылка на материал>
#
#
# В рамках задания предполагается работа только с одной (первой) страницей результатов поисковой выдачи для каждого запроса. Материалы в датафрейме не должны дублироваться, если они попадали в результаты поиска для нескольких запросов из списка.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
def search_on_habr(enter):
    
    url = 'https://habr.com/ru/search/'
    
    habr_blog = pd.DataFrame()
    for word in enter:
        req = requests.get(url, { 'q' : word}).text
        
    soup = BeautifulSoup(req)
    
    news = soup.find_all('article', class_='tm-articles-list__item')
    for new in news:
        if new.find('a', 'tm-article-snippet__title-link'):
            title = new.find('a', 'tm-article-snippet__title-link').text
        elif new.find('h2', 'm-megapost-snippet__title'):
            title = new.find('h2', 'm-megapost-snippet__title').text
        else:
            title = 'Без заголовка'
            
        if new.find('span', 'tm-article-snippet__datetime-published'):
            date = new.find('span', 'tm-article-snippet__datetime-published').text
        else:
            data = new.find('time', 'tm-megapost-snippet__datetime-published').text
            
        if new.find('a', 'tm-article-snippet__title-link'):
            link = new.find('a', 'tm-article-snippet__title-link').get('href')
            
            row = { 'date' : date, 'title' : title, 'link' : link}
            habr_blog = pd.concat([habr_blog, pd.DataFrame([row])])
                
    return habr_blog.reset_index(drop = True)



search_on_habr(['python', 'анализ данных'])
# Out:
#                           date  \
# 0       25  июля  2012 в 13:29
# 1       25  июля  2017 в 13:47
# 2     14  января  2021 в 10:00
# 3     21  января  2019 в 11:21
# 4        14  мая  2020 в 13:39
# 5     16  апреля  2020 в 07:10
# 6     13  ноября  2021 в 19:15
# 7    10  декабря  2021 в 13:15
# 8    18  октября  2021 в 15:08
# 9       18  июня  2014 в 15:19
# 10      30  июня  2014 в 23:06
# 11   13  октября  2014 в 14:00
# 12      27  июня  2017 в 13:51
# 13      28  июля  2014 в 13:10
# 14   11  августа  2014 в 10:47
# 15  14  сентября  2014 в 19:54
# 16    23  ноября  2014 в 16:49
# 17    18  января  2015 в 18:02
# 18    5  октября  2014 в 19:57
#
#                                                 title  \
# 0                       Пять лет Школе анализа данных
# 1                 10 лет Школе анализа данных Яндекса
# 2   Что такое бессерверный SQL? И как использовать...
# 3   Как мы строим систему обработки, хранения и ан...
# 4   Ubic создаст платформу для анализа данных о мо...
# 5   Microsoft анонсировала запуск «Планетарного ко...
# 6   Владимир Путин выступил с Германом Грефом на к...
# 7   Интенсив для повышения квалификации: как испол...
# 8   AI Journey Contest 2021: какие задачи мы подго...
# 9   Обзор наиболее интересных материалов по анализ...
# 10  Обзор наиболее интересных материалов по анализ...
# 11  Обзор наиболее интересных материалов по анализ...
# 12  Использование Python и Excel для обработки и а...
# 13  Обзор наиболее интересных материалов по анализ...
# 14  Обзор наиболее интересных материалов по анализ...
# 15  Обзор наиболее интересных материалов по анализ...
# 16  Обзор наиболее интересных материалов по анализ...
# 17  Обзор наиболее интересных материалов по анализ...
# 18  Обзор наиболее интересных материалов по анализ...
#
#                                        link
# 0           /ru/company/yandex/blog/148443/
# 1           /ru/company/yandex/blog/334066/
# 2        /ru/company/microsoft/blog/537064/
# 3   /ru/company/sibur_official/blog/436632/
# 4                        /ru/news/t/501944/
# 5                        /ru/news/t/497474/
# 6                        /ru/news/t/588991/
# 7     /ru/company/netologyru/news/t/594683/
# 8      /ru/company/sbercloud/news/t/584084/
# 9                          /ru/post/226641/
# 10                         /ru/post/228187/
# 11                         /ru/post/240139/
# 12            /ru/company/otus/blog/331746/
# 13                         /ru/post/231323/
# 14                         /ru/post/232879/
# 15                         /ru/post/236757/
# 16                         /ru/post/243967/
# 17                         /ru/post/248165/
# 18                         /ru/post/239247/
